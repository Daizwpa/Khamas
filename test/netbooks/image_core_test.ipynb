# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    # %load_ext autoreload
# %autoreload 2

from utils.image_core import imread, imshow, imresize, imSave
import numpy as np
from Controller.PreprocessImage import PreProcess

# %%
image_path = "C:\\Users\\User\\Desktop\\Dataset of Meloidogyne spp\\Meloidogyne 1\\01.tif"

Processor = PreProcess(216, 384, 0)

# %%
img = Processor.process(image_path)
imshow(img)

# %%
path_to_save = "C:\\Users\\User\\Desktop\\image.png"
imSave(image=img, path=path_to_save)
